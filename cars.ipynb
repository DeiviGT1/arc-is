# %%
import numpy as np
import seaborn as sns
from ipywidgets import interact
from sklearn.preprocessing import LabelEncoder
from wordcloud import WordCloud
from IPython.display import clear_output
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as mtick

csv = pd.read_csv("cars.csv")

# %%
csv["brand"] = csv["Name"].apply(lambda x: x.split(" ")[0])

csv['reference'] = csv['Name'].apply(lambda x: x.split(' ', 1)[1])

csv["Engine"] = csv["Engine"].str.replace(" CC", "").astype(float)

csv["Power"] = csv["Power"].str.replace(" bhp", "").astype(float)

#The Mileage is represented on kmlp
csv["Mileage"] = np.where(csv["Mileage"].str.split(" ", expand=True)[1] == "kmpl", 
                          csv["Mileage"].str.split(" ", expand=True)[0].astype(float),  
                          csv["Mileage"].str.split(" ", expand=True)[0].astype(float)*0.712/(1.60934*0.264172)
                          )

csv["New_Price"].fillna("0 Lakh", inplace=True)
csv["New_Price"] = np.where(csv["New_Price"].str.split(" ", expand=True)[1] == "Cr",
                            csv["New_Price"].str.split(" ", expand=True)[0].astype(float)*10000000,
                            csv["New_Price"].str.split(" ", expand=True)[0].astype(float)*100000
                            )

csv["Price"] = csv["Price"].astype(float)*100000

csv.drop(["Name", "Unnamed: 0"], axis=1, inplace=True)

# %%
csv[csv["brand"] == "Chevrolet"]
# Out:
#        Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 137        Pune  2014              38800    Petrol       Manual      First
# 171      Jaipur  2012              88000    Diesel       Manual      First
# 175      Jaipur  2007             118500    Petrol       Manual      First
# 222       Kochi  2016              60813    Petrol       Manual     Second
# 231      Mumbai  2013              74000    Diesel       Manual      First
# ...         ...   ...                ...       ...          ...        ...
# 5586  Hyderabad  2013              57352    Diesel    Automatic      First
# 5743       Pune  2007              81000    Petrol       Manual      First
# 5748     Mumbai  2014              18000    Petrol       Manual      First
# 5779    Kolkata  2013              25000    Petrol       Manual      First
# 5846  Hyderabad  2011              47000    Diesel       Manual      First
#
#       Mileage  Engine   Power  Seats  New_Price     Price      brand  \
# 137     18.60  1199.0   76.80    5.0        0.0  285000.0  Chevrolet
# 171     25.44   936.0   57.60    5.0        0.0  150000.0  Chevrolet
# 175     12.90  1598.0  102.50    5.0        0.0  125000.0  Chevrolet
# 222     18.60  1199.0   76.80    5.0        0.0  332000.0  Chevrolet
# 231     25.44   936.0   57.60    5.0        0.0  265000.0  Chevrolet
# ...       ...     ...     ...    ...        ...       ...        ...
# 5586    14.39  1998.0  163.70    5.0        0.0  650000.0  Chevrolet
# 5743    15.26  1150.0   74.90    5.0        0.0  130000.0  Chevrolet
# 5748    13.70  1399.0   98.82    7.0        0.0  335000.0  Chevrolet
# 5779    18.60  1199.0   79.40    5.0        0.0  175000.0  Chevrolet
# 5846    25.44   936.0   57.60    5.0        0.0  250000.0  Chevrolet
#
#                      reference
# 137             Beat LT Option
# 171             Beat Diesel LT
# 175    Optra Magnum 1.6 LS BS3
# 222                    Beat LT
# 231             Beat Diesel LT
# ...                        ...
# 5586              Cruze LTZ AT
# 5743          Aveo U-VA 1.2 LS
# 5748  Enjoy Petrol LS 7 Seater
# 5779                   Beat LS
# 5846               Beat Diesel
#
# [120 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

csv_2 = csv.copy()
csv_2 = csv_2[csv_2["reference"]=="XUV500 W8 2WD"]

X = csv_2["Year"].values.reshape(-1, 1)
y = csv_2["Price"].values.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
csv["reference"].value_counts()
# Out:
# XUV500 W8 2WD               49
# Swift VDI                   45
# Swift Dzire VDI             34
# City 1.5 S MT               34
# i10 Sportz                  30
#                             ..
# S60 D4 SUMMUM                1
# Fiesta Titanium 1.5 TDCi     1
# Scorpio S10 AT 4WD           1
# i20 1.2 Era                  1
# Xylo D4 BSIV                 1
# Name: reference, Length: 1804, dtype: int64

# %%
csv_2
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 89         Delhi  2014              58000    Diesel       Manual      First
# 103        Delhi  2012              65000    Diesel       Manual     Second
# 155       Mumbai  2012              32792    Diesel       Manual      First
# 430        Kochi  2013              61672    Diesel       Manual      First
# 625        Delhi  2012              72450    Diesel       Manual      First
# 728    Ahmedabad  2015              72007    Diesel       Manual      First
# 853        Delhi  2011              66000    Diesel       Manual      First
# 1218     Kolkata  2013              43000    Diesel       Manual      First
# 1387      Mumbai  2012              37000    Diesel       Manual      First
# 1445       Delhi  2012              75000    Diesel       Manual     Second
# 1699       Delhi  2012              88000    Diesel       Manual      First
# 1726       Kochi  2014              70963    Diesel       Manual      First
# 1773     Kolkata  2013              87284    Diesel       Manual      First
# 2009      Jaipur  2014              70669    Diesel       Manual      First
# 2048  Coimbatore  2016              41840    Diesel       Manual      First
# 2097       Kochi  2014              49663    Diesel       Manual      First
# 2162   Ahmedabad  2014              67000    Diesel       Manual     Second
# 2250   Bangalore  2014              55000    Diesel       Manual      First
# 2278       Delhi  2015              36096    Diesel       Manual      First
# 2654   Bangalore  2015              76000    Diesel       Manual     Second
# 2727       Kochi  2013              73648    Diesel       Manual      First
# 2742  Coimbatore  2015              36836    Diesel       Manual      First
# 2748       Kochi  2015              59182    Diesel       Manual      First
# 2855  Coimbatore  2016              59711    Diesel       Manual      First
# 3050  Coimbatore  2013             130790    Diesel       Manual      First
# 3173     Chennai  2011             126000    Diesel       Manual      Third
# 3560  Coimbatore  2015              65100    Diesel       Manual      First
# 3627       Kochi  2013              87736    Diesel       Manual      First
# 3645       Delhi  2014              86000    Diesel       Manual      First
# 3709   Ahmedabad  2014              31000    Diesel       Manual      First
# 3743  Coimbatore  2015              39335    Diesel       Manual      First
# 3773        Pune  2011              90000    Diesel       Manual     Second
# 3841      Mumbai  2016             120000    Diesel       Manual      First
# 4077      Mumbai  2015              83000    Diesel       Manual      First
# 4168   Bangalore  2013              71231    Diesel       Manual     Second
# 4177     Kolkata  2013              44000    Diesel       Manual      First
# 4179       Kochi  2013              61591    Diesel       Manual      First
# 4392        Pune  2012              95000    Diesel       Manual      First
# 4590     Kolkata  2013              55886    Diesel       Manual      First
# 3841     15.1  2179.0  140.0    7.0        0.0  1200000.0  Mahindra
# 4077     16.0  2179.0  140.0    7.0        0.0   900000.0  Mahindra
# 4168     16.0  2179.0  140.0    7.0        0.0   975000.0  Mahindra
# 4177     16.0  2179.0  140.0    7.0        0.0   725000.0  Mahindra
# 4179     16.0  2179.0  140.0    7.0        0.0   682000.0  Mahindra
# 4392     15.1  2179.0  140.0    7.0        0.0   721000.0  Mahindra
# 4590     16.0  2179.0  140.0    7.0        0.0   725000.0  Mahindra
# 4666     15.1  2179.0  140.0    7.0        0.0   650000.0  Mahindra
# 4730     16.0  2179.0  140.0    7.0        0.0   640000.0  Mahindra
# 4851     15.1  2179.0  140.0    7.0        0.0  1009000.0  Mahindra
# 4922     15.1  2179.0  140.0    7.0        0.0   800000.0  Mahindra
# 5026     15.1  2179.0  140.0    7.0        0.0   750000.0  Mahindra
# 5066     15.1  2179.0  140.0    7.0        0.0   650000.0  Mahindra
# 5078     15.1  2179.0  140.0    7.0        0.0   900000.0  Mahindra
# 5214     16.0  2179.0  140.0    7.0        0.0  1659000.0  Mahindra
# 5242     15.1  2179.0  140.0    7.0        0.0   620000.0  Mahindra
# 5791     16.0  2179.0  140.0    7.0        0.0   825000.0  Mahindra
#
#           reference
# 89    XUV500 W8 2WD
# 103   XUV500 W8 2WD
# 155   XUV500 W8 2WD
# 430   XUV500 W8 2WD
# 625   XUV500 W8 2WD
# 728   XUV500 W8 2WD
# 853   XUV500 W8 2WD
# 1218  XUV500 W8 2WD
# 1387  XUV500 W8 2WD
# 1445  XUV500 W8 2WD
# 1699  XUV500 W8 2WD
# 1726  XUV500 W8 2WD
# 1773  XUV500 W8 2WD
# 2009  XUV500 W8 2WD
# 2048  XUV500 W8 2WD
# 2097  XUV500 W8 2WD
# 2162  XUV500 W8 2WD
# 2250  XUV500 W8 2WD
# 2278  XUV500 W8 2WD
# 2654  XUV500 W8 2WD
# 2727  XUV500 W8 2WD
# 2742  XUV500 W8 2WD
# 2748  XUV500 W8 2WD
# 2855  XUV500 W8 2WD
# 3050  XUV500 W8 2WD
# 3173  XUV500 W8 2WD
# 3560  XUV500 W8 2WD
# 3627  XUV500 W8 2WD
# 3645  XUV500 W8 2WD
# 3709  XUV500 W8 2WD
# 3743  XUV500 W8 2WD
# 3773  XUV500 W8 2WD
# 3841  XUV500 W8 2WD
# 4077  XUV500 W8 2WD
# 4168  XUV500 W8 2WD
# 4177  XUV500 W8 2WD
# 4179  XUV500 W8 2WD
# 4392  XUV500 W8 2WD
# 4590  XUV500 W8 2WD
# 4666  XUV500 W8 2WD
# 4730  XUV500 W8 2WD
# 4851  XUV500 W8 2WD
# 4922  XUV500 W8 2WD
# 5026  XUV500 W8 2WD
# 5066  XUV500 W8 2WD
# 5078  XUV500 W8 2WD
# 5214  XUV500 W8 2WD
# 5242  XUV500 W8 2WD
# 5791  XUV500 W8 2WD
